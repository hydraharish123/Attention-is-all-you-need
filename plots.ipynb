# %%
import pandas as pd

# %%
df = pd.read_csv('./output/metrics_log.csv')

# %%
df
# Out:
#      Model    Attention  Accuracy      F1  Precision  Recall    Loss
# 0      RNN  NoAttention    0.4882  0.3280     0.2441  0.4998  0.6977
# 1      RNN     Bahdanau    0.8638  0.8638     0.8640  0.8641  0.3240
# 2      RNN          Dot    0.4882  0.3280     0.2441  0.4998  0.6958
# 3      RNN      General    0.8545  0.8544     0.8568  0.8555  0.3437
# 4      RNN       Concat    0.8520  0.8510     0.8577  0.8505  0.3525
# 5     LSTM  NoAttention    0.5118  0.3389     0.7559  0.5002  0.6929
# 6     LSTM     Bahdanau    0.8843  0.8842     0.8844  0.8841  0.2844
# 7     LSTM          Dot    0.8740  0.8739     0.8739  0.8740  0.3005
# 8     LSTM      General    0.5117  0.3385     0.2558  0.5000  0.6928
# 9     LSTM       Concat    0.8807  0.8806     0.8835  0.8817  0.2897
# 10   BiRNN  NoAttention    0.5138  0.3481     0.5786  0.5023  0.7113
# 11   BiRNN     Bahdanau    0.8668  0.8667     0.8668  0.8667  0.3130
# 12   BiRNN          Dot    0.5295  0.5289     0.5308  0.5306  0.6867
# ...

# %%
## for each type, compare accuracy eg. RNN ---> None, Bahdanau, Dot, General, Dot 
RNN_df = df[df['Model'] == 'RNN']
RNN_df
# Out:
#   Model    Attention  Accuracy      F1  Precision  Recall    Loss
# 0   RNN  NoAttention    0.4882  0.3280     0.2441  0.4998  0.6977
# 1   RNN     Bahdanau    0.8638  0.8638     0.8640  0.8641  0.3240
# 2   RNN          Dot    0.4882  0.3280     0.2441  0.4998  0.6958
# 3   RNN      General    0.8545  0.8544     0.8568  0.8555  0.3437
# 4   RNN       Concat    0.8520  0.8510     0.8577  0.8505  0.3525

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(data=RNN_df, x="Attention", y="Accuracy")
# Out:
# <Axes: xlabel='Attention', ylabel='Accuracy'>
